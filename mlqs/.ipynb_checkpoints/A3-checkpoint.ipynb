# %%
import os
import numpy as np
import pandas as pd
from scipy.signal import resample

# Constants
data_root = "./data/"
SAMPLE_RATE = 60  # Hz

# Window sizes (in samples) per activity
window_sizes = {
    "walking": 200,   #
    # "running": 300,
    "biking": 200,
    "sitting": 200,   #
    "stairs": 200     #
}
activities = list(window_sizes.keys())

# Sensors and their axis columns
sensors = {
    "Accelerometer.csv": ["Acceleration x (m/s^2)", "Acceleration y (m/s^2)", "Acceleration z (m/s^2)"],
    "Gyroscope.csv":    ["Gyroscope x (rad/s)",    "Gyroscope y (rad/s)",    "Gyroscope z (rad/s)"],
    "Linear Acceleration.csv": ["Linear Acceleration x (m/s^2)", "Linear Acceleration y (m/s^2)", "Linear Acceleration z (m/s^2)"]
}

def load_activity_data(activity):
    """
    Loads and merges all sensor streams for a given activity into a single DataFrame,
    aligned by timestamp and resampled to uniform SAMPLE_RATE.
    """
    dfs = []
    time_index = None
    for fname, axes in sensors.items():
        path = os.path.join(data_root, activity, fname)
        df = pd.read_csv(path, sep=';')
        # assume first column is time in seconds
        t = df.iloc[:, 0].values
        if time_index is None:
            # create uniform time grid
            duration = t[-1] - t[0]
            n_samples = int(duration * SAMPLE_RATE)
            uniform_t = np.linspace(t[0], t[-1], n_samples)
            time_index = uniform_t
        # resample each axis to the uniform grid
        arr = []
        for axis in axes:
            signal = df[axis].dropna().values
            resampled = np.interp(time_index, t, signal)
            arr.append(resampled)
        # shape: (n_channels, n_samples)
        data = np.vstack(arr).T
        cols = [f"{os.path.splitext(fname)[0]}_{ax}" for ax in ['x','y','z']]
        dfs.append(pd.DataFrame(data, columns=cols))
    # merge on index
    merged = pd.concat(dfs, axis=1)
    return merged.values  # shape (n_samples, n_channels)


def make_windows(X, activity):
    """
    Splits multivariate signal X into non-overlapping windows for the given activity.
    Returns X_windows and corresponding labels.
    """
    ws = window_sizes[activity]
    n_samples, n_channels = X.shape
    n_windows = n_samples // ws
    Xw = X[:n_windows * ws].reshape(n_windows, ws, n_channels)
    y = np.full(n_windows, activities.index(activity), dtype=int)
    print(Xw.shape)
    return Xw, y

# %%
# Build dataset
X_list, y_list = [], []
for act in activities:
    X_signal = load_activity_data(act)          # (n_samples, n_channels)
    Xw, yw = make_windows(X_signal, act)        # (n_windows, ws, n_channels), (n_windows,)
    X_list.append(Xw)
    y_list.append(yw)
# Out:
# (684, 200, 9)
# (376, 200, 9)
# (265, 200, 9)
# (537, 200, 9)

# %%
X = np.vstack(X_list)  # (total_windows, ws, n_channels)
y = np.concatenate(y_list)

# Shuffle dataset
perm = np.random.RandomState(42).permutation(len(X))
X = X[perm]
y = y[perm]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Conv1D, Flatten, Dense,
    LSTM, GRU,
    Input, MultiHeadAttention, Add, LayerNormalization, GlobalAveragePooling1D
)
from tensorflow.keras.optimizers import Adam


# 2) Train/test split
X_tr, X_te, y_tr, y_te = train_test_split(
    X, y,
    test_size=0.4,
    random_state=42,
    stratify=y
)

# 3) Scale per-channel (flatten→scale→reshape)
n_tr, T, C = X_tr.shape
scaler = StandardScaler()
X_tr_flat = scaler.fit_transform(X_tr.reshape(-1, C))
X_te_flat = scaler.transform(X_te.reshape(-1, C))
X_tr = X_tr_flat.reshape(n_tr, T, C)
X_te = X_te_flat.reshape(X_te.shape[0], T, C)

n_classes = len(np.unique(y))

# 4) Keras fit & report helper
def fit_and_report_keras(model, name, epochs=10, batch_size=32):
    model.compile(
        optimizer=Adam(),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    print(f"\n=== Training {name} ===")
    model.fit(
        X_tr, y_tr,
        validation_split=0.1,
        epochs=epochs,
        batch_size=batch_size,
        verbose=2
    )
    loss, acc = model.evaluate(X_te, y_te, verbose=0)
    print(f"{name} — test accuracy: {acc:.3f}")

# 5) 1D-CNN
cnn = Sequential([
    Conv1D(64, kernel_size=3, activation='relu', input_shape=(T, C)),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(n_classes, activation='softmax')
])
fit_and_report_keras(cnn, "1D-CNN")

# 6) LSTM
lstm = Sequential([
    LSTM(64, input_shape=(T, C)),
    Dense(100, activation='relu'),
    Dense(n_classes, activation='softmax')
])
fit_and_report_keras(lstm, "LSTM")

# 7) GRU
gru = Sequential([
    GRU(64, input_shape=(T, C)),
    Dense(100, activation='relu'),
    Dense(n_classes, activation='softmax')
])
fit_and_report_keras(gru, "GRU")

# 8) Transformer Encoder
inp = Input(shape=(T, C))
# 8.1) project to embedding dim
x = Dense(64)(inp)
# 8.2) self‐attention block
attn = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
x = Add()([x, attn])
x = LayerNormalization()(x)
# 8.3) pool & classify
x = GlobalAveragePooling1D()(x)
x = Dense(100, activation='relu')(x)
out = Dense(n_classes, activation='softmax')(x)
transformer = Model(inp, out)

fit_and_report_keras(transformer, "Transformer Encoder")
# Out:
# === Training 1D-CNN ===
# Epoch 1/10
# /home/troy/VU_HW/mlqs/venv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-06-20 17:56:32.315136: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 32/32 - 1s - 33ms/step - accuracy: 0.8746 - loss: 0.3963 - val_accuracy: 0.9821 - val_loss: 0.1216
# Epoch 2/10
# 32/32 - 0s - 11ms/step - accuracy: 0.9881 - loss: 0.0481 - val_accuracy: 0.9821 - val_loss: 0.0451
# Epoch 3/10
# 32/32 - 0s - 12ms/step - accuracy: 0.9940 - loss: 0.0235 - val_accuracy: 0.9911 - val_loss: 0.0158
# Epoch 4/10
# 32/32 - 0s - 11ms/step - accuracy: 0.9940 - loss: 0.0175 - val_accuracy: 0.9821 - val_loss: 0.0334
# Epoch 5/10
# 32/32 - 0s - 11ms/step - accuracy: 0.9950 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 6/10
# 32/32 - 0s - 12ms/step - accuracy: 0.9990 - loss: 0.0047 - val_accuracy: 0.9911 - val_loss: 0.0117
# Epoch 7/10
# 32/32 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 8/10
# 32/32 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 9/10
# 32/32 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 10/10
# 32/32 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0061
# 1D-CNN — test accuracy: 0.991
#
# === Training LSTM ===
# Epoch 1/10
# /home/troy/VU_HW/mlqs/venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 - 2s - 69ms/step - accuracy: 0.6697 - loss: 0.9612 - val_accuracy: 0.8750 - val_loss: 0.4837
# Epoch 2/10
# 32/32 - 1s - 32ms/step - accuracy: 0.8975 - loss: 0.3202 - val_accuracy: 0.8750 - val_loss: 0.2487
# Epoch 3/10
# 32/32 - 1s - 31ms/step - accuracy: 0.9184 - loss: 0.2115 - val_accuracy: 0.9821 - val_loss: 0.1444
# Epoch 4/10
# 32/32 - 1s - 32ms/step - accuracy: 0.9731 - loss: 0.1158 - val_accuracy: 0.9554 - val_loss: 0.2235
# Epoch 5/10
# 32/32 - 1s - 31ms/step - accuracy: 0.9483 - loss: 0.1610 - val_accuracy: 0.9554 - val_loss: 0.1604
# Epoch 6/10
# 32/32 - 1s - 31ms/step - accuracy: 0.9652 - loss: 0.1228 - val_accuracy: 0.9732 - val_loss: 0.1092
# Epoch 7/10
# 32/32 - 1s - 31ms/step - accuracy: 0.9692 - loss: 0.1189 - val_accuracy: 0.9732 - val_loss: 0.1259
# Epoch 8/10
# 32/32 - 1s - 31ms/step - accuracy: 0.9761 - loss: 0.0835 - val_accuracy: 0.9821 - val_loss: 0.0794
# Epoch 9/10
# 32/32 - 1s - 33ms/step - accuracy: 0.9821 - loss: 0.0626 - val_accuracy: 0.9821 - val_loss: 0.0679
# Epoch 10/10
# 32/32 - 1s - 31ms/step - accuracy: 0.9861 - loss: 0.0554 - val_accuracy: 0.9554 - val_loss: 0.1534
# LSTM — test accuracy: 0.964
#
# === Training GRU ===
# Epoch 1/10
# 32/32 - 2s - 73ms/step - accuracy: 0.6547 - loss: 1.0764 - val_accuracy: 0.8036 - val_loss: 0.7819
# Epoch 2/10
# 32/32 - 1s - 36ms/step - accuracy: 0.8736 - loss: 0.5028 - val_accuracy: 0.8929 - val_loss: 0.3196
# Epoch 3/10
# 32/32 - 1s - 34ms/step - accuracy: 0.9343 - loss: 0.2222 - val_accuracy: 0.9732 - val_loss: 0.1694
# Epoch 4/10
# 32/32 - 1s - 35ms/step - accuracy: 0.9662 - loss: 0.1347 - val_accuracy: 0.9732 - val_loss: 0.1397
# Epoch 5/10
# 32/32 - 1s - 36ms/step - accuracy: 0.9701 - loss: 0.1238 - val_accuracy: 0.9821 - val_loss: 0.1136
# Epoch 6/10
# 32/32 - 1s - 35ms/step - accuracy: 0.9791 - loss: 0.0831 - val_accuracy: 0.9821 - val_loss: 0.1077
# Epoch 7/10
# 32/32 - 1s - 37ms/step - accuracy: 0.9851 - loss: 0.0684 - val_accuracy: 0.9821 - val_loss: 0.0959
# Epoch 8/10
# 32/32 - 1s - 35ms/step - accuracy: 0.9851 - loss: 0.0598 - val_accuracy: 0.9821 - val_loss: 0.0949
# Epoch 9/10
# 32/32 - 1s - 34ms/step - accuracy: 0.9851 - loss: 0.0640 - val_accuracy: 0.9821 - val_loss: 0.0920
# Epoch 10/10
# 32/32 - 1s - 34ms/step - accuracy: 0.9821 - loss: 0.0717 - val_accuracy: 0.9821 - val_loss: 0.0823
# GRU — test accuracy: 0.977
#
# === Training Transformer Encoder ===
# Epoch 1/10
# 32/32 - 5s - 144ms/step - accuracy: 0.8428 - loss: 0.4953 - val_accuracy: 0.9643 - val_loss: 0.1610
# Epoch 2/10
# 32/32 - 3s - 96ms/step - accuracy: 0.9701 - loss: 0.1161 - val_accuracy: 0.9732 - val_loss: 0.1007
# Epoch 3/10
# 32/32 - 3s - 88ms/step - accuracy: 0.9791 - loss: 0.0809 - val_accuracy: 0.9732 - val_loss: 0.0625
# Epoch 4/10
# 32/32 - 3s - 87ms/step - accuracy: 0.9871 - loss: 0.0547 - val_accuracy: 0.9911 - val_loss: 0.0381
# Epoch 5/10
# 32/32 - 3s - 89ms/step - accuracy: 0.9920 - loss: 0.0409 - val_accuracy: 0.9821 - val_loss: 0.0429
# Epoch 6/10
# 32/32 - 3s - 90ms/step - accuracy: 0.9930 - loss: 0.0359 - val_accuracy: 0.9821 - val_loss: 0.0309
# Epoch 7/10
# 32/32 - 3s - 87ms/step - accuracy: 0.9950 - loss: 0.0297 - val_accuracy: 0.9821 - val_loss: 0.0249
# Epoch 8/10
# 32/32 - 3s - 87ms/step - accuracy: 0.9920 - loss: 0.0254 - val_accuracy: 0.9821 - val_loss: 0.0244
# Epoch 9/10
# 32/32 - 3s - 92ms/step - accuracy: 0.9940 - loss: 0.0219 - val_accuracy: 0.9911 - val_loss: 0.0174
# Epoch 10/10
# 32/32 - 3s - 87ms/step - accuracy: 0.9950 - loss: 0.0185 - val_accuracy: 0.9911 - val_loss: 0.0161
# Transformer Encoder — test accuracy: 0.991
